# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)
print(os.getcwd())

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./simulations/sim_istarmazz_highwall"

if os.path.exists(work_dir):
    
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py") or file.endswith(".png"):
        shutil.copy(file, work_dir)
shutil.copytree(os.getcwd() + "/potentials", work_dir + "/potentials", dirs_exist_ok=True)
os.chdir(work_dir)
print(os.getcwd())
# Out:
# /home/elias/Documents/stapleTIS/toytis
# /home/elias/Documents/stapleTIS/toytis/simulations/sim_istarmazz_highwall

# %%
###### 1D POTENTIALS #####

# intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [-0.1, 0., 0.1, 0.2, 0.3]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]
# intfs = [-0.35, -0.25, 0., 0.25, 0.35]
intfs = [-0.35, -0.25, -0.12, 0.12, 0.25, 0.35]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 100000,
            "dt": 0.01,
            "temperature": .3,
            "friction": 10.,
            "max_cycles": 100000,
            "p_shoot": 0.8,
            "include_stateB": False,
            'prime_both_starts': False,
            'max_paths': 5
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 100000,
             "dt": 0.01,
             "temperature": .3,
             "friction": 5.,
             "max_cycles": 1000000,
             "p_shoot": 0.8,    
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0
}

istarset = {"interfaces" : intfs,
             "simtype" : "i*", 
             "method" : "load",
             "max_len" : 200000,
             "dt": 0.005,
             "temperature": 1.,
             "friction": 5.,
             "high_friction": True,
             "max_cycles": 100000,
             "p_shoot": 0.9,        
             "include_stateB": False,
             'prime_both_starts': True,
             'snake_Lmax': 0,
             'max_paths': 5,
             "dim": 1,
             "mass": 1,
             "v_ord": True,
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("\ninterfaces = {}\n".format(intfs) +
            #  "zero_left = {}\n".format(istarset["zero_left"]) +
             "timestep = {}\n".format(istarset["dt"]))
sim = Simulation(istarset)
logger.info("Full settings:\n{}".format(sim.settings))

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.WARNING)


#sim.run()
sim.run()

# sim<do+shooting+;oves5-
# plot+pqths
# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]

# %%
###### 2D POTENTIALS #####

# intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [0.20, 0.325, 0.55, 0.69, 0.75, 0.90]
intfs = [0.20, 0.27, 0.39, 0.49, 0.56, 0.655, 0.74, 0.84]
# intfs = [-3, -2.4, -2.15, -1.98, -1.83, -1.66, -1.25, -0.8, -0.585, -0.449, -0.349, -0.261, -0.171, 0, 0.171, 0.261]
# intfs = [-0.1, 0., 0.1, 0.2, 0.3]
# intfs = [-1.9, -1.65, -1, -0.4, 0.6, 1.2, 1.9]
# intfs = [-2.7, -1.8, -0.7, 0.8, 1.35, 2.45, 3.7]
# intfs = [-2.9, -1.8, -1, -0.6, 0, 0.6, 1, 1.5, 2.3, 2.8, 3.7]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 200000,
            "dt": 0.01,
            "temperature": .3,
            "friction": 10.,
            "max_cycles": 100000,
            "p_shoot": 0.8,
            "include_stateB": False,
            'prime_both_starts': False,
            'snake_Lmax': 0,
            'max_paths': 5,
            'save_pe2': False,
            'pe2_N': 0
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 100000,
             "dt": 0.01,
             "temperature": .3,
             "friction": 5.,
             "max_cycles": 1000000,
             "p_shoot": 0.8,    
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0
}

istarset = {"interfaces" : intfs,
             "simtype" : "i*", 
             "method" : "load",
             "max_len" : 200000,
             "dt": 0.01,
             "temperature": 0.07,
             "friction": 5.,
             "high_friction": False,
             "max_cycles": 100000,
             "p_shoot": 0.9,        
             "include_stateB": False,
             'prime_both_starts': True,
             'snake_Lmax': 0,
             'max_paths': 25,
             'save_pe2': False,
             'pe2_N': 0,
             "dim": 2,
             "mass": 1,
             'permeability': False,
             'zero_left': 0.1,
             'v_ord': False
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("\ninterfaces = {}\n".format(intfs) +
            #  "zero_left = {}\n".format(istarset["zero_left"]) +
             "timestep = {}\n".format(istarset["dt"]))
sim = Simulation(istarset)
logger.info("Full settings:\n{}".format(sim.settings))
# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.WARNING)

#sim.run()
sim.run()

# sim<do+shooting+;oves5-
# plot+pqths
# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 237, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 124, in __init__
#     logger.info("gauss_a:",self.gauss_a)
# Message: 'gauss_a:'
# Arguments: (500.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 237, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 125, in __init__
#     logger.info("gauss_b:",self.gauss_b)
# Message: 'gauss_b:'
# Arguments: (0.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 237, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 126, in __init__
#     logger.info("gauss_c:",self.gauss_c)
# Message: 'gauss_c:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 237, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 127, in __init__
#     logger.info("lenx:", self.lenx)
# Message: 'lenx:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 237, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 128, in __init__
#     logger.info("leny:", self.leny)
# Message: 'leny:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 262, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 124, in __init__
#     logger.info("gauss_a:",self.gauss_a)
# Message: 'gauss_a:'
# Arguments: (500.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 262, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 125, in __init__
#     logger.info("gauss_b:",self.gauss_b)
# Message: 'gauss_b:'
# Arguments: (0.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 262, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 126, in __init__
#     logger.info("gauss_c:",self.gauss_c)
# Message: 'gauss_c:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 262, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 127, in __init__
#     logger.info("lenx:", self.lenx)
# Message: 'lenx:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
# ...
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 287, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 125, in __init__
#     logger.info("gauss_b:",self.gauss_b)
# Message: 'gauss_b:'
# Arguments: (0.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 287, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 126, in __init__
#     logger.info("gauss_c:",self.gauss_c)
# Message: 'gauss_c:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 287, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 127, in __init__
#     logger.info("lenx:", self.lenx)
# Message: 'lenx:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 1160, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 999, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 703, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/logging/__init__.py", line 392, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel_launcher.py", line 18, in <module>
#     app.launch_new_instance()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/traitlets/config/application.py", line 1075, in launch_instance
#     app.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelapp.py", line 739, in start
#     self.io_loop.start()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 641, in run_forever
#     self._run_once()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/base_events.py", line 1986, in _run_once
#     handle._run()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/asyncio/events.py", line 88, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 545, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 534, in process_one
#     await dispatch(*args)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 437, in dispatch_shell
#     await result
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 362, in execute_request
#     await super().execute_request(stream, ident, parent)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/kernelbase.py", line 778, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/ipkernel.py", line 449, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/ipykernel/zmqshell.py", line 549, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3075, in run_cell
#     result = self._run_cell(
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3130, in _run_cell
#     result = runner(coro)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/async_helpers.py", line 128, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3334, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3517, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/.conda/envs/pastime/lib/python3.12/site-packages/IPython/core/interactiveshell.py", line 3577, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_104412/2302473216.py", line 80, in <module>
#     sim = Simulation(istarset)
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 71, in __init__
#     self.create_ensembles()
#   File "/home/elias/Documents/stapleTIS/toytis/simulation.py", line 287, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 109, in __init__
#     self.set_engine()
#   File "/home/elias/Documents/stapleTIS/toytis/ensemble.py", line 119, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/home/elias/Documents/stapleTIS/toytis/engine.py", line 188, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/tunnelistarwalls.png")
#   File "/home/elias/Documents/stapleTIS/toytis/potentials/mazepotential_mixed.py", line 128, in __init__
#     logger.info("leny:", self.leny)
# Message: 'leny:'
# Arguments: (1.0,)

# %%
for ens in sim.ensembles:
    print(ens.intfs)
# Out:
# {'L': -inf, 'M': None, 'R': -0.35}
# {'L': -0.35, 'M': None, 'R': -0.25, 'all': [-0.35, -0.25, -0.12, 0.12, 0.25, 0.35]}
# {'L': -0.35, 'M': -0.25, 'R': -0.12, 'all': [-0.35, -0.25, -0.12, 0.12, 0.25, 0.35]}
# {'L': -0.25, 'M': -0.12, 'R': 0.12, 'all': [-0.35, -0.25, -0.12, 0.12, 0.25, 0.35]}
# {'L': -0.12, 'M': 0.12, 'R': 0.25, 'all': [-0.35, -0.25, -0.12, 0.12, 0.25, 0.35]}
# {'L': 0.12, 'M': 0.25, 'R': 0.35, 'all': [-0.35, -0.25, -0.12, 0.12, 0.25, 0.35]}

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
