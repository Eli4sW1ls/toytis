# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./sim_istar_dbfix0"

if os.path.exists(work_dir):
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py"):
        shutil.copy(file, work_dir)
os.chdir(work_dir)
print(os.getcwd())
# Out:
# /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/sim_istar_dbfix0

# %%
intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 100000,
            "dt": 0.01,
            "temperature": .3,
            "friction": 10.,
            "max_cycles": 100000,
            "p_shoot": 0.8,
            "include_stateB": False,
            'prime_both_starts': False,
            'snake_Lmax': 0,
            'max_paths': 5,
            'save_pe2': False,
            'pe2_N': 0
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 100000,
             "dt": 0.01,
             "temperature": .3,
             "friction": 5.,
             "max_cycles": 1000000,
             "p_shoot": 0.8,    
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0
}

istarset = {"interfaces" : intfs,
             "simtype" : "i*", 
             "method" : "load",
             "max_len" : 100000,
             "dt": 0.01,
             "temperature": .3,
             "friction": 10.,
             "max_cycles": 1000000,
             "p_shoot": 1,          # only shooting for now
             "include_stateB": False,
             'prime_both_starts': True,
             'snake_Lmax': 0,
             'max_paths': 25,
             'save_pe2': False,
             'pe2_N': 0
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("Hello world!")
logger.info("\ninterfaces = {}\n".format(intfs) +
            #  "zero_left = {}\n".format(istarset["zero_left"]) +
             "timestep = {}\n".format(istarset["dt"]))
sim = Simulation(istarset)

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.WARNING)

#sim.run()
sim.run()

# sim<do+shooting+;oves5-
# plot+pqths
# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 72
#      69 logging.getLogger("matplotlib").setLevel(logging.WARNING)
#      71 #sim.run()
# ---> 72 sim.run()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:294, in Simulation.run(self)
#     292 logger.info("-" * 80)
#     293 if np.random.rand() < p_shoot:
# --> 294     self.do_shooting_moves()
#     295 #     if self.cycle % 5 == 0:
#     296 #         ps = []
#     297 #         for i in range(len(self.intfs)):
#    (...)
#     305 #         plt.close('all')
#     306 else:
#     307     self.do_swap_moves()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:92, in Simulation.do_shooting_moves(self)
#      90 self.cycle += 1
#      91 for ens in self.ensembles:
# ---> 92     status, trial = shooting_move(ens)
#      93     logger.info("Shooting move in {} resulted in {}".format(
#      94         ens.name, status))
#      95     # print(status, trial.ptype if type(trial) is not tuple else trial[0].ptype)
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:137, in shooting_move(ens, level)
#     135         return "ACC", (ext_path, ptype)
#     136 else:
# --> 137     bext_status, bext_tuple = propagate(ens, new_path.phasepoints[0], -1., shoot_maxlen-len(new_path.orders), True)
#     138     if bext_status != "ACC":
#     139         logger.debug("Backwards extension not successful: {}".format(
#     140             bext_status))
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:576, in propagate(ens, sh, reverse, maxlen, ext)
#     573 pos_star = None
#     574 while run_worthy:
#     575     #logger.debug("ph = %s", ph)
# --> 576     ph = ens.engine.step(ph)
#     577     op = ens.orderparameter.calculate(ph)
#     578     phs.append((ph[0], reverse*ph[1]))
#
# KeyboardInterrupt:

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
