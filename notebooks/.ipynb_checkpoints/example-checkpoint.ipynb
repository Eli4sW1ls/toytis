# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./sim_retiscosb3"

if os.path.exists(work_dir):
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py"):
        shutil.copy(file, work_dir)
os.chdir(work_dir)
print(os.getcwd())
# Out:
# /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/sim_retiscosb3

# %%
# intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]
intfs = [-0.1, 0., 0.1, 0.2, 0.3 ]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 200000,
            "dt": 0.0002,
            "temperature": 1.,
            "friction": 5.,
            "max_cycles": 30000,
            "p_shoot": 0.9,
            "include_stateB": False,
            'prime_both_starts': False,
            'snake_Lmax': 0,
            'max_paths': 5,
            'save_pe2': False,
            'pe2_N': 0,
            "mass": 1,
            "dim": 1,
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 200000,
             "dt": 0.0002,
             "temperature": 1.,
             "friction": 5.,
             "max_cycles": 30000,
             "p_shoot": 0.9,
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0,
             "mass": 1,
             "dim": 1,
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("Hello world!")
sim = Simulation(retisset)

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.DEBUG)

#sim.run()
sim.run()

# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[2], line 57
#      54 logging.getLogger("matplotlib").setLevel(logging.DEBUG)
#      56 #sim.run()
# ---> 57 sim.run()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:309, in Simulation.run(self)
#     296     self.do_shooting_moves()
#     297 #     if self.cycle % 5 == 0:
#     298 #         ps = []
#     299 #         for i in range(len(self.intfs)):
#    (...)
#     307 #         plt.close('all')
#     308 else:
# --> 309     self.do_swap_moves()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:126, in Simulation.do_swap_moves(self)
#     124     self.do_null_move(-1, "00")
#     125 for i in range(0, len(self.ensembles) - 1, 2):
# --> 126     self.do_swap_move(i)
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:154, in Simulation.do_swap_move(self, i)
#     151     self.ensembles[i+1].update_data(status, trial2, "s-", self.cycle)
#     153 elif self.simtype == "repptis":
# --> 154     status, trial1, trial2 = repptis_swap(self.ensembles, i)
#     155     logger.info("Swap move {} <-> {} resulted in {}".format(
#     156         self.ensembles[i].name, self.ensembles[i+1].name, status))
#     157     self.ensembles[i].update_data(status, trial1, "s+", self.cycle)
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:352, in repptis_swap(ensembles, idx)
#     349     else:
#     350         trial1 = Path(ph_overlap1 + tuple1[0], op_overlap1 + tuple1[1],
#     351                       ens1.id)
# --> 352     return status1, trial0, trial1
#     354 # If we reached this point, we have two new paths. We now check whether they
#     355 # satisfy the crossing conditions.
#     356 if ens0.ens_type != 'PPTIS_0plusmin_primed':  # 0+-: new_path_0 already made
#
# UnboundLocalError: local variable 'trial0' referenced before assignment

# %%
for ens in sim.ensembles:
    print(ens.intfs)
# Out:
# {'L': -inf, 'M': None, 'R': -0.1}
# {'L': -0.1, 'M': None, 'R': 0.0}
# {'L': -0.1, 'M': 0.0, 'R': 0.3}
# {'L': -0.1, 'M': 0.1, 'R': 0.3}
# {'L': -0.1, 'M': 0.2, 'R': 0.3}

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
fig2,ax2 =plt.subplots()
sim.ensembles[0].engine.potential.plot_force(ax2)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
