# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./sim_retis0fix"

if os.path.exists(work_dir):
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py"):
        shutil.copy(file, work_dir)
os.chdir(work_dir)
print(os.getcwd())
# Out:
# /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/sim_retiscosb3

# %%
# intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]
intfs = [-0.1, 0., 0.1, 0.2, 0.3 ]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 200000,
            "dt": 0.0002,
            "temperature": 1.,
            "friction": 5.,
            "max_cycles": 30000,
            "p_shoot": 0.9,
            "include_stateB": False,
            'prime_both_starts': False,
            'snake_Lmax': 0,
            'max_paths': 5,
            'save_pe2': False,
            'pe2_N': 0,
            "mass": 1,
            "dim": 1,
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 200000,
             "dt": 0.0002,
             "temperature": 1.,
             "friction": 5.,
             "max_cycles": 30000,
             "p_shoot": 0.9,
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0,
             "mass": 1,
             "dim": 1,
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("Hello world!")
sim = Simulation(retisset)

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.DEBUG)

#sim.run()
sim.run()

# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 57
#      54 logging.getLogger("matplotlib").setLevel(logging.DEBUG)
#      56 #sim.run()
# ---> 57 sim.run()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:302, in Simulation.run(self)
#     300 logger.info("-" * 80)
#     301 if np.random.rand() < p_shoot:
# --> 302     self.do_shooting_moves()
#     303 #     if self.cycle % 5 == 0:
#     304 #         ps = []
#     305 #         for i in range(len(self.intfs)):
#    (...)
#     313 #         plt.close('all')
#     314 else:
#     315     self.do_swap_moves()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:92, in Simulation.do_shooting_moves(self)
#      90 self.cycle += 1
#      91 for ens in self.ensembles:
# ---> 92     status, trial = shooting_move(ens)
#      93     logger.info("Shooting move in {} resulted in {}".format(
#      94         ens.name, status))
#      95     # print(status, trial.ptype if type(trial) is not tuple else trial[0].ptype)
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:75, in shooting_move(ens, level)
#      71     return bw_status, Path(bw_tuple[0]+[shootpoint],
#      72                            bw_tuple[1]+[shootpoint_op],
#      73                            ens.id, [ptype, 0, bw_status, shootpoint_op])
#      74 # if successful, we continue propagating forwards
# ---> 75 fw_status, fw_tuple = propagate(ens, shootpoint, 1.,
#      76                                 shoot_maxlen-len(bw_tuple[0]))
#      77 # if unsuccessful, return the status and the partially propagated path
#      78 if fw_status != "ACC":
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:576, in propagate(ens, sh, reverse, maxlen, ext)
#     573 pos_star = None
#     574 while run_worthy:
#     575     #logger.debug("ph = %s", ph)
# --> 576     ph = ens.engine.step(ph)
#     577     op = ens.orderparameter.calculate(ph)
#     578     phs.append((ph[0], reverse*ph[1]))
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py:127, in step(self, ph)
#     118         self.mdsteps += 1
#     120         return (x_new, v_new)
#     122     # # Calculate the new position using the current velocity.
#     123     # x_new = x + v * self.dt
#     124     # force = self.potential.force((x_new, v))
#     125
#     126     # # calculate the stochastic force
# --> 127     # xi = np.random.normal(0, 1, self.dim)[0]
#     128
#     129     # # update the velocity and position using the Langevin equation
#     130     # v_new = v * self.one_minus_gammadt\
#     131     #         + (force * self.dtdivmass)\
#     132     #         + self.sigma * xi
#     133
#     134     # self.mdsteps += 1
#     135
#     136     # return (x_new, v_new)
#     138 def draw_velocities(self):
#     139     """
#     140     Draw velocities from the Maxwell-Boltzmann distribution at temperature T
#     141     for a particle of dimension dim.
#    (...)
#     145         Velocity drawn from the Maxwell-Boltzmann distribution
#     146     """
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/cos_bump_series.py:70, in CosBumpSeriesWalls.force(self, ph)
#      67 deltaf = self.params['deltaf']
#      68 nbump  = self.params['nbump']
# ---> 70 assert bleft < bright
#      71 assert bleft >= xleft
#      72 assert bright <= xright
#
# KeyboardInterrupt:

# %%
for ens in sim.ensembles:
    print(ens.intfs)
# Out:
# {'L': -inf, 'M': None, 'R': -0.1}
# {'L': -0.1, 'M': None, 'R': 0.0}
# {'L': -0.1, 'M': 0.0, 'R': 0.3}
# {'L': -0.1, 'M': 0.1, 'R': 0.3}
# {'L': -0.1, 'M': 0.2, 'R': 0.3}

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
fig2,ax2 =plt.subplots()
sim.ensembles[0].engine.potential.plot_force(ax2)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
