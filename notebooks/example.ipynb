# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./sim_repptiswell"

if os.path.exists(work_dir):
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py"):
        shutil.copy(file, work_dir)
os.chdir(work_dir)
print(os.getcwd())
# Out:
# /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/sim_repptiswell

# %%
intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 100000,
            "dt": 0.01,
            "temperature": .3,
            "friction": 10.,
            "max_cycles": 100000,
            "p_shoot": 0.8,
            "include_stateB": False,
            'prime_both_starts': False,
            'snake_Lmax': 0,
            'max_paths': 5,
            'save_pe2': False,
            'pe2_N': 0
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 100000,
             "dt": 0.01,
             "temperature": .3,
             "friction": 10.,
             "max_cycles": 1000000,
             "p_shoot": 1,
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("Hello world!")
sim = Simulation(repptisset)

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.DEBUG)

#sim.run()
sim.run()

# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# 499
# 499
# 499
# 499
# 499
# 499
# 499
# 499
# 499
# 499
# 665
# 15
# 220
# 592
# 531
# 19
# 35
# 347
# 63
# 30
# 857
# 7
# 435
# 722
# 254
# 67
# 26
# 570
# 57
# 9
# 4672
# 11
# 131
# 522
# 484
# 68
# 37
# 405
# 67
# 21
# 1681
# 12
# 201
# 560
# 325
# 90
# 33
# 130
# 78
# 60
# 5775
# 8
# 213
# 608
# 344
# 248
# 44
# 170
# 98
# 117
# 3845
# 10
# 493
# 530
# 358
# 476
# 23
# 296
# 244
# 160
# 3654
# 9
# 528
# 177
# 591
# 1014
# 23
# 505
# 144
# 305
# 4162
# 11
# 318
# 95
# 796
# 1186
# 16
# 258
# 104
# 149
# 884
# 21
# 501
# 51
# 127
# 1243
# 31
# 202
# 132
# 257
# 987
# 33
# 161
# 84
# 367
# 926
# 33
# 465
# 173
# 140
# 1543
# 51
# 579
# 244
# 752
# 701
# 27
# 828
# 226
# 68
# 3366
# 81
# 310
# 137
# 196
# 2040
# 59
# 209
# 345
# 78
# 1434
# 33
# 440
# 80
# 356
# 646
# 63
# 717
# 163
# 45
# 1166
# 30
# 696
# 107
# 1016
# 712
# 65
# 830
# 107
# 24
# 1701
# 18
# 479
# 242
# 881
# 1040
# 203
# 458
# 193
# 39
# 1276
# 67
# 230
# 670
# 497
# 1067
# 806
# 129
# 154
# 48
# 1332
# 48
# 303
# 1282
# 567
# 789
# 2105
# 298
# 87
# 81
# 1715
# 29
# 652
# 653
# 817
# 909
# 1206
# 868
# 92
# 20
# 1143
# 3
# 50
# 676
# 1150
# 984
# 447
# 760
# 182
# 56
# 995
# 15
# 28
# 719
# 817
# 1338
# 273
# 296
# 208
# 62
# 1661
# 6
# 37
# 149
# 247
# 1768
# 534
# 379
# 256
# 367
# 1740
# 10
# 24
# 30
# 305
# 466
# 1772
# 218
# 139
# 169
# 2524
# 41
# 52
# 152
# 202
# 2000
# 1629
# 813
# 126
# 90
# 739
# 31
# 75
# 215
# 1027
# 252
# 1387
# 922
# 277
# 257
# 1709
# 34
# 45
# 126
# 1064
# 840
# 1326
# 171
# 10
# 178
# 42
# 10
# 40
# 82
# 814
# 1036
# 437
# 196
# 12
# 450
# 67
# 11
# 33
# 271
# 383
# 417
# 16
# 217
# 12
# 349
# 178
# 3
# 30
# 75
# 589
# 259
# 13
# 277
# 18
# 87
# 272
# 2
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 52
#      49 logging.getLogger("matplotlib").setLevel(logging.DEBUG)
#      51 #sim.run()
# ---> 52 sim.run()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:294, in Simulation.run(self)
#     292 logger.info("-" * 80)
#     293 if np.random.rand() < p_shoot:
# --> 294     self.do_shooting_moves()
#     295     # if self.cycle % 5 == 0:
#     296     #     ps = []
#     297     #     for i in range(len(self.intfs)):
#    (...)
#     305     #     plt.close('all')
#     306 else:
#     307     self.do_swap_moves()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:92, in Simulation.do_shooting_moves(self)
#      90 self.cycle += 1
#      91 for ens in self.ensembles:
# ---> 92     status, trial = shooting_move(ens)
#      93     logger.info("Shooting move in {} resulted in {}".format(
#      94         ens.name, status))
#      95     # print(status, trial.ptype if type(trial) is not tuple else trial[0].ptype)
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:50, in shooting_move(ens, level)
#      48 else:
#      49     n_ph = pathlen
# ---> 50     sh_id = np.random.randint(1,n_ph-1)
#      51 shootpoint = (path.phasepoints[sh_id][0],
#      52               ens.engine.draw_velocities())
#      53 shoot_maxlen = min(n_ph/np.random.random(), ens.max_len)
#
# File numpy/random/mtrand.pyx:782, in numpy.random.mtrand.RandomState.randint()
#
# File numpy/random/_bounded_integers.pyx:1334, in numpy.random._bounded_integers._rand_int64()
#
# ValueError: low >= high

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()
# Out:
# libGL error: failed to open /dev/dri/card0: Permission denied
# libGL error: failed to open /dev/dri/card0: Permission denied
# libGL error: failed to load driver: iris

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
