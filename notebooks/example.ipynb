# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./sim"

if os.path.exists(work_dir):
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py"):
        shutil.copy(file, work_dir)
os.chdir(work_dir)

# %%
intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
            "simtype" : "retis", 
            "method" : "load",
            "max_len" : 100000,
            "dt": 0.01,
            "temperature": .3,
            "friction": 10.,
            "max_cycles": 1000000,
            "p_shoot": 0.8,
            "include_stateB": False,
            'prime_both_starts': False,
            'snake_Lmax': 0,
            'max_paths': 5,
            'save_pe2': False,
            'pe2_N': 0
}
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 100000,
             "dt": 0.01,
             "temperature": .3,
             "friction": 10.,
             "max_cycles": 1000000,
             "p_shoot": 0.8,
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("Hello world!")
sim = Simulation(retisset)

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.WARNING)

#sim.run()
sim.run()

# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 51
#      48 logging.getLogger("matplotlib").setLevel(logging.WARNING)
#      50 #sim.run()
# ---> 51 sim.run()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:281, in Simulation.run(self)
#     279 logger.info("-" * 80)
#     280 if np.random.rand() < p_shoot:
# --> 281     self.do_shooting_moves()
#     282 else:
#     283     self.do_swap_moves()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py:92, in Simulation.do_shooting_moves(self)
#      90 self.cycle += 1
#      91 for ens in self.ensembles:
# ---> 92     status, trial = shooting_move(ens)
#      93     logger.info("Shooting move in {} resulted in {}".format(
#      94         ens.name, status))
#      95     ens.update_data(status, trial, "sh", self.cycle)
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:59, in shooting_move(ens, level)
#      53 logger.debug("Shooting from ph {} (idx: {}) with op {}".format(
#      54     shootpoint, sh_id, shootpoint_op))
#      55 # We now start propagating the shootpoint backwards first, because often
#      56 # the backwards part (corresponding to the starting condition) is more
#      57 # restrictive than the forwards part (corresponding to the end condition).
#      58 # propagate backwards. Maxlen = shoot_maxlen-1, because shootpoint is 1
# ---> 59 bw_status, bw_tuple = propagate(ens, shootpoint, -1., shoot_maxlen-1)
#      60 # if unsuccessful, return the status and the partially propagated path
#      61 if bw_status != "ACC":
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/moves.py:511, in propagate(ens, sh, reverse, maxlen)
#     508 ph = (sh[0], reverse*sh[1])
#     509 while run_worthy:
#     510     #logger.debug("ph = %s", ph)
# --> 511     ph = ens.engine.step(ph)
#     512     op = ens.orderparameter.calculate(ph)
#     513     phs.append((ph[0], reverse*ph[1]))
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py:54, in LangevinEngine.step(self, ph)
#      52 x, v = ph
#      53 # Calculate the potential and force at the current phasepoint
# ---> 54 _, force = self.potential.potential_and_force(ph)
#      56 # Calculate the stochastic force based on the temperature and friction
#      57 stochastic_force = \
#      58     np.sqrt(2 * self.temperature * self.friction) * np.random.randn()
#
# File /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potential.py:48, in Potential.potential_and_force(self, ph)
#      46 doublewell = self.a*x**4 - self.b*(x - self.c)**2
#      47 bump = self.d * np.sin(2. * np.pi * x / self.p)
# ---> 48 modulation = (1.-1. / (1 + np.exp(-5. * (np.abs(x) - 3.*self.p))))
#      49 pot = doublewell + bump * modulation
#      51 # force
#
# KeyboardInterrupt:

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
