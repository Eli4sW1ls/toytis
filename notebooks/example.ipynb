# %%
import os
import shutil
import logging
import matplotlib.pyplot as plt
import numpy as np
dir_path = "../"
os.chdir(dir_path)

from simulation import Simulation
from funcs import plot_paths, overlay_paths
# %matplotlib qt

work_dir = "./simulations/sim_retismaze"

if os.path.exists(work_dir):
    shutil.rmtree(work_dir)
if not os.path.exists(work_dir):
    os.mkdir(work_dir)
# copy all py files of cwd to test
for file in os.listdir(os.getcwd()):
    if file.endswith(".py"):
        shutil.copy(file, work_dir)
shutil.copytree(os.getcwd() + "/potentials", work_dir + '/potentials')
os.chdir(work_dir)
print(os.getcwd())
# Out:
# /mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulations/sim_retismaze

# %%
# intfs = [-1., -0.75, -0.5, -0.25, 0., 0.25, 0.5, 0.75, 1., 1.25]
# intfs = [-1., -0.75, -0.5, -0.25, 0.]
# intfs = [-0.1, 0., 0.1, 0.2, 0.3]
intfs = [0.20, 0.325, 0.55, 0.69, 0.75, 0.90]

# Set-up the simulation keys for RETIS
retisset = {"interfaces" : intfs,
             "simtype" : "retis", 
             "method" : "load",
             "max_len" : 200000,
             "dt": 0.01,
             "temperature": 0.07,
             "friction": 25.,
             "high_friction": False,
             "max_cycles": 100000,
             "p_shoot": 0.9,        
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 25,
             'save_pe2': False,
             'pe2_N': 0,
             "dim": 2,
             "mass": 1,
             'permeability': True,
             'zero_left': 0.1
}
            # "interfaces" : intfs,
            # "simtype" : "retis", 
            # "method" : "load",
            # "max_len" : 200000,
            # "dt": 0.0002,
            # "temperature": 1.,
            # "friction": 5.,
            # "high_friction": True,
            # "max_cycles": 100000,
            # "p_shoot": 1,
            # "include_stateB": False,
            # 'prime_both_starts': False,
            # 'snake_Lmax': 0,
            # 'max_paths': 5,
            # 'save_pe2': False,
            # 'pe2_N': 0,
            # "mass": 1,
            # "dim": 1,
# }
# or for REPPTIS
repptisset = {"interfaces" : intfs,
             "simtype" : "repptis", 
             "method" : "load",
             "max_len" : 200000,
             "dt": 0.0002,
             "temperature": 1.,
             "high_friction": True,
             "friction": 5.,
             "max_cycles": 100000,
             "p_shoot": 0.8,
             "include_stateB": False,
             'prime_both_starts': False,
             'snake_Lmax': 0,
             'max_paths': 5,
             'save_pe2': False,
             'pe2_N': 0,
             "mass": 1,
             "dim": 1,
}

logger = logging.getLogger()
file_handler = logging.FileHandler("logging.log")
formatter = logging.Formatter('[%(levelname)s] %(name)s %(funcName)s %(lineno)d: %(message)s')
file_handler.setFormatter(formatter)
logger.addHandler(file_handler)
logger.setLevel(logging.INFO)
logger.info("Hello world!")
sim = Simulation(retisset)

# set loglevel to warning for matplotlib
logging.getLogger("matplotlib").setLevel(logging.DEBUG)

#sim.run()
sim.run()

# Check the simulation output in the pathensemble.txt files 
# The output is compatible with pyretisanalyse. But you'll have to change
# the dirnames from [0, 1, 2, ...] --> [000, 001, 002, ...]
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 238, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 124, in __init__
#     logger.info("gauss_a:",self.gauss_a)
# Message: 'gauss_a:'
# Arguments: (500.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 238, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 125, in __init__
#     logger.info("gauss_b:",self.gauss_b)
# Message: 'gauss_b:'
# Arguments: (0.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 238, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 126, in __init__
#     logger.info("gauss_c:",self.gauss_c)
# Message: 'gauss_c:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 238, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 127, in __init__
#     logger.info("lenx:", self.lenx)
# Message: 'lenx:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 238, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 128, in __init__
#     logger.info("leny:", self.leny)
# Message: 'leny:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 263, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 124, in __init__
#     logger.info("gauss_a:",self.gauss_a)
# Message: 'gauss_a:'
# Arguments: (500.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 263, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 125, in __init__
#     logger.info("gauss_b:",self.gauss_b)
# Message: 'gauss_b:'
# Arguments: (0.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 263, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 126, in __init__
#     logger.info("gauss_c:",self.gauss_c)
# Message: 'gauss_c:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 263, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 127, in __init__
#     logger.info("lenx:", self.lenx)
# Message: 'lenx:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
# ...
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 288, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 125, in __init__
#     logger.info("gauss_b:",self.gauss_b)
# Message: 'gauss_b:'
# Arguments: (0.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 288, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 126, in __init__
#     logger.info("gauss_c:",self.gauss_c)
# Message: 'gauss_c:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 288, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 127, in __init__
#     logger.info("lenx:", self.lenx)
# Message: 'lenx:'
# Arguments: (1.0,)
# --- Logging error ---
# Traceback (most recent call last):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 1100, in emit
#     msg = self.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 943, in format
#     return fmt.format(record)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 678, in format
#     record.message = record.getMessage()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/logging/__init__.py", line 368, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 196, in _run_module_as_main
#     return _run_code(code, main_globals, None,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/runpy.py", line 86, in _run_code
#     exec(code, run_globals)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelapp.py", line 736, in start
#     self.io_loop.start()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/tornado/platform/asyncio.py", line 195, in start
#     self.asyncio_loop.run_forever()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 603, in run_forever
#     self._run_once()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/base_events.py", line 1909, in _run_once
#     handle._run()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/asyncio/events.py", line 80, in _run
#     self._context.run(self._callback, *self._args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 516, in dispatch_queue
#     await self.process_one()
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 505, in process_one
#     await dispatch(*args)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 412, in dispatch_shell
#     await result
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/kernelbase.py", line 740, in execute_request
#     reply_content = await reply_content
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/ipkernel.py", line 422, in do_execute
#     res = shell.run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/ipykernel/zmqshell.py", line 546, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3051, in run_cell
#     result = self._run_cell(
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3106, in _run_cell
#     result = runner(coro)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/async_helpers.py", line 129, in _pseudo_sync_runner
#     coro.send(None)
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3311, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3493, in run_ast_nodes
#     if await self.run_code(code, result, async_=asy):
#   File "/home/elias/anaconda3/envs/pastime/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_2592333/3888725535.py", line 75, in <module>
#     sim = Simulation(retisset)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 72, in __init__
#     self.create_ensembles()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/simulation.py", line 288, in create_ensembles
#     self.ensembles.append(Ensemble(ens_set))
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 120, in __init__
#     self.set_engine()
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/ensemble.py", line 129, in set_engine
#     self.engine = ndLangevinEngine(self.settings)
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/engine.py", line 183, in __init__
#     self.potential = Maze2D_color(mazefig="potentials/maze.png")
#   File "/mnt/0bf0c339-34bb-4500-a5fb-f3c2a863de29/DATA/PyRETIS3/toytis/potentials/mazepotential_mixed.py", line 128, in __init__
#     logger.info("leny:", self.leny)
# Message: 'leny:'
# Arguments: (1.0,)

# %%
for ens in sim.ensembles:
    print(ens.intfs)
# Out:
# {'L': -inf, 'M': None, 'R': -0.1}
# {'L': -0.1, 'M': None, 'R': 0.3}
# {'L': -0.1, 'M': 0.0, 'R': 0.3}
# {'L': -0.1, 'M': 0.1, 'R': 0.3}
# {'L': -0.1, 'M': 0.2, 'R': 0.3}

# %%
# plot the potential and the interfaces
fig,ax =plt.subplots()
sim.ensembles[0].engine.potential.plot_potential(ax)
fig2,ax2 =plt.subplots()
sim.ensembles[0].engine.potential.plot_force(ax2)
for intf in sim.intfs:
    ax.axvline(intf, color="black", linestyle="--")
fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 3
#       1 # plot the potential and the interfaces
#       2 fig,ax =plt.subplots()
# ----> 3 sim.ensembles[0].engine.potential.plot_potential(ax)
#       4 fig2,ax2 =plt.subplots()
#       5 sim.ensembles[0].engine.potential.plot_force(ax2)
#
# AttributeError: 'FlatWall1D' object has no attribute 'plot_potential'

# %%
# A Langevin engine is used. This can be swapped for a velocity verlet engine if 
# you want NVE dynamics. (But you'll have to change this in ensemble.py, where
# the engine object is initialized.)
